# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\third_year\sem_2\nlp\lab\.venv\lib\site-packages (3.9.3)
# Requirement already satisfied: click in d:\third_year\sem_2\nlp\lab\.venv\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in d:\third_year\sem_2\nlp\lab\.venv\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in d:\third_year\sem_2\nlp\lab\.venv\lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in d:\third_year\sem_2\nlp\lab\.venv\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in d:\third_year\sem_2\nlp\lab\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from nltk.util import ngrams
from collections import defaultdict

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text = """
natural language processing is interesting
natural language processing is useful
machine learning is useful
"""

# %%
# Tokenize
tokens = nltk.word_tokenize(text.lower())

# %%
# Create bigrams
bigrams = list(ngrams(tokens, 2))

# %%
# Build frequency dictionary
model = defaultdict(list)

# %%
for w1, w2 in bigrams:
    model[w1].append(w2)

# %%
# Auto-complete function
def autocomplete(word):
    if word in model:
        return model[word]
    else:
        return []

# %%
# Test
print("Next words after 'language':", autocomplete("language"))
print("Next words after 'processing':", autocomplete("processing"))
# Out:
# Next words after 'language': ['processing', 'processing']
# Next words after 'processing': ['is', 'is']
